# %% [markdown]
# # Drug Annotation and Inferences

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action='ignore')

# %%
def ot_drug_query(query_string, chemid, base_url):
    # Build query string to get general information about AR and genetic constraint and tractability assessments 
    # Set variables object of arguments to be passed to endpoint
    variables = {"chemblId": chemid}
    
    # Perform POST request and check status code of response
    r = requests.post(base_url, json={"query": query_string, "variables": variables})
    
    
    # Transform API response from JSON into Python dictionary and print in console
    api_response = json.loads(r.text)
    
    if r.status_code != 200:
        return r.status_code
    else:
        return api_response

# %%
# read in significant drug target results
# ma replicated 
ma_hits2 = pd.read_csv('sig_genes_ma_chemblthresh2.csv')

# all sig hits
all_hits2 = pd.read_csv('all_sig_genes_chemblthresh2.csv')

# %%
# disease EFO Ids
dx_efo = {'AD': 'MONDO_0004975', 'LOAD' : 'EFO_1001870', 'ALS': 'MONDO_0004976', 'ALSt4': 'MONDO_0011223', 'FTD&|ALS' : 'MONDO_0007105','FTD': 'MONDO_0017276', 'LBD':'EFO_0006792', 'PD':'MONDO_0005180', 'Parkinsonian': 'MONDO_0021095','PSP': 'MONDO_0010997'}

# %% [markdown]
# ## 1. MultiAncestry replicated hits Thresh 2

# %%
# extract chemblid list
ma_chembl = list(ma_hits2.chemblid.unique())
len(ma_chembl)
# Out:
# 1

# %%
# query to get list of approved diseases where drug can be used to treat
query_string = """
      query drugs($chemblId: String!){
        drug(chemblId: $chemblId){
        name
        id
        approvedIndications
          }
        }
    """

# Set base URL of GraphQL API endpoint
base_url = "https://api.platform.opentargets.org/api/v4/graphql"

# %%
chembl_dict = {}
no_drug_chembl = []
no_linked_dx = []
for cid in ma_chembl:
    # run ot query
    out = ot_drug_query(query_string,cid, base_url)
    if isinstance(out, int):
        print('something broke')  
    elif isinstance(out, dict):
         # list to holde associated diseases
        asc_dx = []
        # check if chembleid returned any drugs OT recognizes
        if type(out['data']['drug']) == type(None):
            no_drug_chembl.append(cid)
            # if no approved uses put in seperate list
        elif type(out['data']['drug']['approvedIndications']) == type(None):
            no_linked_dx.append(cid)
        else:
            # get name of drug
            #drug_name = out['data']['drug']['name']

            # number of approved indications
            num_dx = len(out['data']['drug']['approvedIndications'])
            for x in range(num_dx):
                efo_id = out['data']['drug']['approvedIndications'][0]

                    # check if 
                if any([True for k,v, in dx_efo.items() if v == efo_id]):
                    asc_dx.append([k for k,v, in dx_efo.items() if v == efo_id][0])
            chembl_dict[cid] = asc_dx

# %% [markdown]
# ## 2. All Significant Hits Threshold 2

# %%
# extract chemblid list
all_chembl = list(all_hits2.chemblid.unique())
len(all_chembl)
# Out:
# 856

# %%
chembl_dict_all = {}
no_drug_chembl_all = []
no_linked_dx_all = []
for cid in all_chembl:
    # run ot query
    out = ot_drug_query(query_string,cid, base_url)
    if isinstance(out, int):
        print('something broke')  
    elif isinstance(out, dict):
         # list to holde associated diseases
        asc_dx_all = []
        # check if chembleid returned any drugs OT recognizes
        if type(out['data']['drug']) == type(None):
            no_drug_chembl_all.append(cid)
            # if no approved uses put in seperate list
        elif type(out['data']['drug']['approvedIndications']) == type(None):
            no_linked_dx_all.append(cid)
        else:
            # number of approved indications
            num_dx = len(out['data']['drug']['approvedIndications'])
            for x in range(num_dx):
                efo_id = out['data']['drug']['approvedIndications'][x]

                    # check if 
                if any([True for k,v, in dx_efo.items() if v == efo_id]):
                    asc_dx_all.append([k for k,v, in dx_efo.items() if v == efo_id][0])
            chembl_dict_all[cid] = asc_dx_all

# %%
# clean out output dictionary in order to get chemblIDs that returned an NDD related approved indication
chembl_dict_ndd_all = {k: v for k, v in chembl_dict_all.items() if v}
# create list of chemblid that returned NDD association
chembl_ndd_all = list(chembl_dict_ndd_all.keys())

# try and get t1 hits together
# clean out output dictionary in order to get chemblIDs that DID NOT returned an NDD related approved indication
chembl_dict_nondd_all = {k: v for k, v in chembl_dict_all.items() if not v}
# create list of chemblid that returned NO NDD association
chembl_nondd_all = list(chembl_dict_nondd_all.keys())

# %%
len(no_linked_dx_all)
# Out:
# 79

# %%
len(chembl_nondd_all)
# Out:
# 370

# %%
len(no_drug_chembl_all)
# Out:
# 403

# %%
# use list of chembl IDs to find tier 2 gene hits
t2_hits_all = all_hits2.query('chemblid == @chembl_ndd_all')

# %%
t2_hits_all.Disease.unique()
# Out:
# array(['AD', 'PD', 'PSP'], dtype=object)

# %%
# use list of chembl IDs to find tier 1 gene hits
t1_hits_all = all_hits2.query('chemblid != @chembl_ndd_all')

t1_hits_all
# Out:
#                          Omic Disease   Gene          probeID    topRSID  \
# 0        Cerebellum_metaBrain      AD    CR1  ENSG00000203710  rs1830763
# 1        Cerebellum_metaBrain      AD    CR1  ENSG00000203710  rs1830763
# 2      Basalganglia_metaBrain      AD    CR1  ENSG00000203710  rs6697005
# 3      Basalganglia_metaBrain      AD    CR1  ENSG00000203710  rs6697005
# 4            Cortex_metaBrain      AD    CR1  ENSG00000203710  rs1830763
# ...                       ...     ...    ...              ...        ...
# 16132           blood_eQTLgen      AD  ERCC2  ENSG00000104884   rs171140
# 16133           blood_eQTLgen      AD  ERCC2  ENSG00000104884   rs171140
# 16134           blood_eQTLgen      AD  ERCC2  ENSG00000104884   rs171140
# 16135           blood_eQTLgen      AD  ERCC2  ENSG00000104884   rs171140
# 16136           blood_eQTLgen      AD  ERCC2  ENSG00000104884   rs171140
#
#           b_SMR    se_SMR         p_SMR   p_SMR_multi   p_HEIDI gene_name  \
# 0      0.245292  0.045868  8.901474e-08  1.723238e-08  0.109188       CR1
# 1      0.245292  0.045868  8.901474e-08  1.723238e-08  0.109188       CR1
# 2      0.165833  0.029748  2.479933e-08  2.479933e-08  0.078615       CR1
# 3      0.165833  0.029748  2.479933e-08  2.479933e-08  0.078615       CR1
# 4      0.147259  0.013974  5.752421e-26  3.826448e-15  0.060285       CR1
# ...         ...       ...           ...           ...       ...       ...
# 16132  0.128369  0.036800  4.861232e-04  1.751872e-06  0.039685     ERCC2
# 16133  0.128369  0.036800  4.861232e-04  1.751872e-06  0.039685     ERCC2
# 16134  0.128369  0.036800  4.861232e-04  1.751872e-06  0.039685     ERCC2
# 16135  0.128369  0.036800  4.861232e-04  1.751872e-06  0.039685     ERCC2
# 16136  0.128369  0.036800  4.861232e-04  1.751872e-06  0.039685     ERCC2
#
#       interaction_types drug_claim_name drug_claim_primary_name    drug_name  \
# 0                   NaN      eculizumab              eculizumab   ECULIZUMAB
# 1                   NaN        CDX-1135                CDX-1135     CDX-1135
# 2                   NaN      eculizumab              eculizumab   ECULIZUMAB
# 3                   NaN        CDX-1135                CDX-1135     CDX-1135
# 4                   NaN      eculizumab              eculizumab   ECULIZUMAB
# ...                 ...             ...                     ...          ...
# 16132               NaN       docetaxel               docetaxel    DOCETAXEL
# 16133               NaN        platinum                platinum     PLATINUM
# 16134               NaN       cisplatin               cisplatin    CISPLATIN
# 16135               NaN     oxaliplatin             oxaliplatin  OXALIPLATIN
# 16136               NaN       etoposide               etoposide    ETOPOSIDE
#
#             chemblid
# 0      CHEMBL1201828
# 1      CHEMBL4297720
# 2      CHEMBL1201828
# 3      CHEMBL4297720
# 4      CHEMBL1201828
# ...              ...
# 16132       CHEMBL92
# 16133  CHEMBL1235478
# 16134    CHEMBL11359
# 16135   CHEMBL414804
# 16136    CHEMBL44657
#
# [16072 rows x 16 columns]

# %%
t1_hits_all.to_csv('tier1hits_all_OT_thresh2.csv', index = None)

# %%
# load in hits that didn't have chemblids
nochembl_sig = pd.read_csv('all_sig_genes_nochemblthresh2.csv')

# %%
# concat significant hits that had no chemblids but were therapeutic to  t1 hits with chemblids
t1_hits_all2 = pd.concat([t1_hits_all, nochembl_sig])

t2_genes = ['MAPT', 'KCNN4', 'ADORA2B']
# remove any t2 gene hits
t1_hits_all2 = t1_hits_all2.query('Gene != @t2_genes')

# %%
t1_hits_all2.Disease.unique()
# Out:
# array(['AD', 'PD', 'LBD', 'PSP'], dtype=object)

# %%
len(t1_hits_all2.Gene.unique())
# Out:
# 41

# %%
# export 
t1_hits_all2.to_csv('tier1hits_all_thresh2.csv', index = None)

# %%
# add label for tier categories
t1_hits_all2['tier'] = 'Tier1'

t2_hits_all['tier'] = 'Tier2'

drug_hits = pd.concat([t1_hits_all2,t2_hits_all])
drug_hits
# Out:
#                          Omic Disease     Gene          probeID     topRSID  \
# 0        Cerebellum_metaBrain      AD      CR1  ENSG00000203710   rs1830763
# 1        Cerebellum_metaBrain      AD      CR1  ENSG00000203710   rs1830763
# 2      Basalganglia_metaBrain      AD      CR1  ENSG00000203710   rs6697005
# 3      Basalganglia_metaBrain      AD      CR1  ENSG00000203710   rs6697005
# 4            Cortex_metaBrain      AD      CR1  ENSG00000203710   rs1830763
# ...                       ...     ...      ...              ...         ...
# 13913             blood_mcrae     PSP     MAPT       cg05772917     rs11012
# 14266             blood_mcrae     PSP     MAPT       cg05772917     rs11012
# 16017         Muscle_Skeletal      PD  ADORA2B  ENSG00000170425   rs1045599
# 16031         Muscle_Skeletal      PD  ADORA2B  ENSG00000170425   rs1045599
# 16114           blood_eQTLgen      AD    KCNN4  ENSG00000104783  rs56681946
#
#           b_SMR    se_SMR         p_SMR   p_SMR_multi   p_HEIDI gene_name  \
# 0      0.245292  0.045868  8.901474e-08  1.723238e-08  0.109188       CR1
# 1      0.245292  0.045868  8.901474e-08  1.723238e-08  0.109188       CR1
# 2      0.165833  0.029748  2.479933e-08  2.479933e-08  0.078615       CR1
# 3      0.165833  0.029748  2.479933e-08  2.479933e-08  0.078615       CR1
# 4      0.147259  0.013974  5.752421e-26  3.826448e-15  0.060285       CR1
# ...         ...       ...           ...           ...       ...       ...
# 13913  5.231440  0.831232  3.102029e-10  6.220856e-11  0.136632      MAPT
# 14266  5.231440  0.831232  3.102029e-10  6.220856e-11  0.136632      MAPT
# 16017  0.081000  0.016160  5.378991e-07  2.729232e-06  0.017355   ADORA2B
# 16031  0.081000  0.016160  5.378991e-07  2.729232e-06  0.017355   ADORA2B
# 16114 -0.050012  0.014573  5.992623e-04  1.008476e-08  0.152656     KCNN4
#
#       interaction_types drug_claim_name drug_claim_primary_name  \
# 0                   NaN      eculizumab              eculizumab
# 1                   NaN        CDX-1135                CDX-1135
# 2                   NaN      eculizumab              eculizumab
# 3                   NaN        CDX-1135                CDX-1135
# 4                   NaN      eculizumab              eculizumab
# ...                 ...             ...                     ...
# 13913               NaN       CARBIDOPA               CARBIDOPA
# 14266               NaN     APOMORPHINE             APOMORPHINE
# 16017               NaN  ISTRADEFYLLINE          ISTRADEFYLLINE
# 16031        antagonist       178102242          ISTRADEFYLLINE
# 16114         activator       135650900                RILUZOLE
#
#             drug_name       chemblid   tier
# 0          ECULIZUMAB  CHEMBL1201828  Tier1
# 1            CDX-1135  CHEMBL4297720  Tier1
# 2          ECULIZUMAB  CHEMBL1201828  Tier1
# 3            CDX-1135  CHEMBL4297720  Tier1
# 4          ECULIZUMAB  CHEMBL1201828  Tier1
# ...               ...            ...    ...
# 13913       CARBIDOPA  CHEMBL1200748  Tier2
# 14266     APOMORPHINE       CHEMBL53  Tier2
# 16017  ISTRADEFYLLINE   CHEMBL431770  Tier2
# 16031  ISTRADEFYLLINE   CHEMBL431770  Tier2
# 16114        RILUZOLE      CHEMBL744  Tier2
#
# [3518 rows x 17 columns]

# %%
drug_hits['drug_name'] = drug_hits.drug_claim_primary_name.str.lower()

drug_hits.drop_duplicates(inplace = True)

# %%
# export all t1 and t2 hits
drug_hits.to_csv('t1t2_hits_drugsthresh2.csv', index = None)

# %%
# export
drug_hits = pd.read_csv('t1t2_hits_drugsthresh2.csv')
